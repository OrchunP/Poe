# %%
import pandas as pd

# %%
poe = pd.read_csv("C:/Users/Orchun/Desktop/jupiter/poe_stats.csv")

# %%
poe
# Out:
#         rank   dead  online                    name  level        class  \
# 0          1  False   False      Tzn_NecroIsFineNow    100  Necromancer
# 1          1  False   False        RaizNeverFirstQT    100  Necromancer
# 2          1  False   False  GucciStreamerAdvantage    100  Necromancer
# 3          1  False   False             ChiroxPrime    100       Slayer
# 4          2  False   False     Cool_NecroIsFineNow    100      Deadeye
# ...      ...    ...     ...                     ...    ...          ...
# 59771  14999   True   False       ПроклятьеРекласта     89  Necromancer
# 59772  15000  False   False       IshibashiSummoner     94  Necromancer
# 59773  15000  False   False                 BLively     73       Slayer
# 59774  15000  False   False                vawddvaw     89    Gladiator
# 59775  15000  False   False                 Reselin     53  Necromancer
#
#                                                       id  experience  \
# ...

# %%
poe.drop("id",inplace=True, axis=1)

# %%
poe
# Out:
#         rank   dead  online                    name  level        class  \
# 0          1  False   False      Tzn_NecroIsFineNow    100  Necromancer
# 1          1  False   False        RaizNeverFirstQT    100  Necromancer
# 2          1  False   False  GucciStreamerAdvantage    100  Necromancer
# 3          1  False   False             ChiroxPrime    100       Slayer
# 4          2  False   False     Cool_NecroIsFineNow    100      Deadeye
# ...      ...    ...     ...                     ...    ...          ...
# 59771  14999   True   False       ПроклятьеРекласта     89  Necromancer
# 59772  15000  False   False       IshibashiSummoner     94  Necromancer
# 59773  15000  False   False                 BLively     73       Slayer
# 59774  15000  False   False                vawddvaw     89    Gladiator
# 59775  15000  False   False                 Reselin     53  Necromancer
#
#        experience       account  challenges        twitch              ladder
# ...

# %%
poe.drop("online",inplace=True, axis=1)

# %%
poe.drop("dead",inplace=True, axis=1)

# %%
poe
# Out:
#         rank                    name  level        class  experience  \
# 0          1      Tzn_NecroIsFineNow    100  Necromancer  4250334444
# 1          1        RaizNeverFirstQT    100  Necromancer  4250334444
# 2          1  GucciStreamerAdvantage    100  Necromancer  4250334444
# 3          1             ChiroxPrime    100       Slayer  4250334444
# 4          2     Cool_NecroIsFineNow    100      Deadeye  4250334444
# ...      ...                     ...    ...          ...         ...
# 59771  14999       ПроклятьеРекласта     89  Necromancer  1786695653
# 59772  15000       IshibashiSummoner     94  Necromancer  2720770853
# 59773  15000                 BLively     73       Slayer   495034029
# 59774  15000                vawddvaw     89    Gladiator  1786638972
# 59775  15000                 Reselin     53  Necromancer    77909816
#
#             account  challenges        twitch              ladder
# 0            TheTzn          40        thetzn           Harbinger
# ...

# %%
poe = poe[poe["ladder"] == "Harbinger"]

# %%
poe
# Out:
#         rank                  name  level        class  experience  \
# 0          1    Tzn_NecroIsFineNow    100  Necromancer  4250334444
# 4          2   Cool_NecroIsFineNow    100      Deadeye  4250334444
# 8          3  Rami_The_Negromaniac    100  Necromancer  4250334444
# 13         4  Guraj_NecroIsFineNow    100       Raider  4250334444
# 18         5                 Ryphe    100    Occultist  4250334444
# ...      ...                   ...    ...          ...         ...
# 59757  14996          iTrofiiforTi     94    Ascendant  2720826701
# 59761  14997                Semirf     94    Chieftain  2720815490
# 59766  14998              Vicoachh     94       Raider  2720813347
# 59770  14999            Imastunboy     94    Berserker  2720777728
# 59772  15000     IshibashiSummoner     94  Necromancer  2720770853
#
#             account  challenges      twitch     ladder
# 0            TheTzn          40      thetzn  Harbinger
# ...

# %%
poe
# Out:
#         rank                  name  level        class  experience  \
# 0          1    Tzn_NecroIsFineNow    100  Necromancer  4250334444
# 4          2   Cool_NecroIsFineNow    100      Deadeye  4250334444
# 8          3  Rami_The_Negromaniac    100  Necromancer  4250334444
# 13         4  Guraj_NecroIsFineNow    100       Raider  4250334444
# 18         5                 Ryphe    100    Occultist  4250334444
# ...      ...                   ...    ...          ...         ...
# 59757  14996          iTrofiiforTi     94    Ascendant  2720826701
# 59761  14997                Semirf     94    Chieftain  2720815490
# 59766  14998              Vicoachh     94       Raider  2720813347
# 59770  14999            Imastunboy     94    Berserker  2720777728
# 59772  15000     IshibashiSummoner     94  Necromancer  2720770853
#
#             account  challenges     ladder
# 0            TheTzn          40  Harbinger
# 4          cooltail          22  Harbinger
# ...

# %%
poe
# Out:
#         rank                  name  level        class  experience  \
# 0          1    Tzn_NecroIsFineNow    100  Necromancer  4250334444
# 4          2   Cool_NecroIsFineNow    100      Deadeye  4250334444
# 8          3  Rami_The_Negromaniac    100  Necromancer  4250334444
# 13         4  Guraj_NecroIsFineNow    100       Raider  4250334444
# 18         5                 Ryphe    100    Occultist  4250334444
# ...      ...                   ...    ...          ...         ...
# 59757  14996          iTrofiiforTi     94    Ascendant  2720826701
# 59761  14997                Semirf     94    Chieftain  2720815490
# 59766  14998              Vicoachh     94       Raider  2720813347
# 59770  14999            Imastunboy     94    Berserker  2720777728
# 59772  15000     IshibashiSummoner     94  Necromancer  2720770853
#
#             account     ladder
# 0            TheTzn  Harbinger
# 4          cooltail  Harbinger
# 8          rami1337  Harbinger
# 13          Guraj93  Harbinger
# ...

# %%
poe.to_excel("poe_data.xlsx")
